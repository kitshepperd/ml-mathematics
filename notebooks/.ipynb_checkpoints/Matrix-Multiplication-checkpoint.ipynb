# %% [markdown]
# ## Matrix Multiplication

# %% [markdown]
# In this notebook I will try to give some intuition into the operation which is a matrix multiplication

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First let's start with a vector which is $2$ in the $\hat{x}$ direction. Similarly our vector has length $1$ in the $\hat{x}$ direction

# %% [markdown]
# $$\begin{pmatrix} 2 \\
# 1 \end{pmatrix} $$

# %% [markdown]
# This vector can be seen below

# %%
fig, ax = plt.subplots()
ax.quiver(0, 0, 1, 0, angles="xy", scale_units="xy", scale=1)
ax.quiver(0, 0, 0, 1, angles="xy", scale_units="xy", scale=1)
ax.quiver(0, 0, *vector, angles="xy", scale_units="xy", scale=1)

ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)
plt.show()

# %% [markdown]
# $$\begin{pmatrix} 1 & 1 \\
# 2 & -3 \end{pmatrix}
# \begin{pmatrix} x_{1} \\
# x_{2} \end{pmatrix} $$

# %%
transform = np.array([[1, 1], [2, -3]])
transform
# Out:
# array([[ 1,  1],
#        [ 2, -3]])

# %%
transform @ vector
# Out:
# array([3, 1])

# %%
fig, ax = plt.subplots()
ax.quiver(0, 0, *(transform @ vector), angles="xy", scale_units="xy", scale=1)
ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)
plt.show()

# %%
np.arange(0, 3)
# Out:
# array([0, 1, 2])

# %%
np.array([0, 1, 2]),np.array([0, 1, 2]))
# Out:
# array([0, 1, 2])
