# %% [markdown]
# # Eigenvectors and Eigenvalues

# %% [markdown]
# In this notebook I will run through an example of finding an eigen-decomposition. Throughout I will provide geometric interpretation of eigenvalues and eigenvectors

# %% [markdown]
# Before diving in, some background on eigen decomposition.

# %% [markdown]
# Supppose we have matrix $A$, its eigen equation is given by
# $$\textbf{Av = $\lambda$ v}$$

# %% [markdown]
# where $\textbf{v}$ is a matrix whose columns are composed of the set of eigenvectos $\{v_{1}, v_{2}, ..., v_{m}\}$ (the value of m occurs from the algebraic multiplicity of the set of eigenvectors), $\lambda$ is the set of eigenvalues associated with each eigenvector

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[2, 3, 0], [1, 4, 3], [0, 0, 1]])

# %% [markdown]
# First lets plot the original unit vectors in the canonical basis and observe how they are transformed by $\textbf{A}$

# %%
X, Y, Z = np.array([1, 0, 0]), np.array([0, 1, 0]), np.array([0, 0, 1])

# %% [markdown]
# As explained in the notebook, transforming a space by matrix $A$ can be seen as transforming the unitvectors

# %%
ax = plt.figure().add_subplot(projection="3d")
lims = 4
ax.quiver(0, 0, 0, *X, color="r")
ax.quiver(0, 0, 0, *Y, color="b")
ax.quiver(0, 0, 0, *Z, color="g")
ax.set_xlim(-lims, lims)
ax.set_ylim(-lims, lims)
ax.set_zlim(-lims, lims)
ax.quiver(0, 0, 0, *(A @ X), color="r")
ax.quiver(0, 0, 0, *(A @ Y), color="b")
ax.quiver(0, 0, 0, *(A @ Z), color="g")
ax.set_xlim(-lims, lims)
ax.set_ylim(-lims, lims)
ax.set_zlim(-lims, lims)
plt.show()

# %% [markdown]
# Here, we can see that our transformation $A$ has adjusted our basis vectors.

# %% [markdown]
# The eigen-decomposition for an equation is given by
# $$A= PDP^{-1}$$

# %% [markdown]
# where P is a matrix whose columns are the eigenvectors of $A$ and $D$ is a diagonal matrix whose non-zero values are the eigenvalues of $A$. For a derivation of this equation see *mathematics for machine learning ref*

# %% [markdown]
# Let's unpick exactly what the eigen-decomposition equation is saying. We can see that our transformation $A$ is equivalent to the three transformations on the RHS.
#
# These transformations are $P$, whose columns are the set of eigenvectos, $D$ a diagonal matrix and $P^{-1}$ the inverse of the eigenvalue matrix.
#
# To understand geometrically we are required to be familiar with a basis change.

# %% [markdown]
# ## Aside: Basis Change

# %% [markdown]
# When referring to column vectors in column vector notation e.g.
# $$ X = \begin{pmatrix} x_{1}\\
# x_{2} \end{pmatrix} $$
#
# There is an implicit assumption that we know the unit vectors $\hat{x_{1}}$ and $\hat{x_{2}}$. In fact these are vital bits of information if we are hoping to understand the vector $X$.
#
# Let's take an example to see how changing the basis vectors can affect the vector we wish to describe.
#
# Suppose we have vector $$ X = \begin{pmatrix} -1\\
# 3 \end{pmatrix} $$
#
# Usually, this would be assumed to be relative to the standard bases i.e.
# $$\hat{x_{1}} = \begin{pmatrix} 1\\
# 0 \end{pmatrix} $$ and
# $$\hat{x_{2}} = \begin{pmatrix} 0\\
# 1 \end{pmatrix} $$
#
# Let's call this vector $X_{s.b}$ (s.b for standard basis)
#
# However, no suppose we took some other bases
# $$\hat{x_{1}} = \begin{pmatrix} 1\\
# 1 \end{pmatrix} , \space  \space \space \space \space \space
# \hat{x_{2}} = \begin{pmatrix} 1\\
# -1 \end{pmatrix} $$

# %%
eig_vals, eig_vecs = np.linalg.eig(A)

# %%
eig_vecs
# Out:
# array([[-9.48683298e-01, -7.07106781e-01,  9.48683298e-01],
#        [ 3.16227766e-01, -7.07106781e-01, -3.16227766e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  9.36222258e-17]])

# %%
eig_vecs[:, 1]
# Out:
# array([-0.70710678, -0.70710678,  0.        ])

# %%
ax = plt.figure().add_subplot(projection="3d")
lims = 4
ax.quiver(0, 0, 0, *(eig_vals[0] * eig_vecs[:, 0]), color="r")
ax.quiver(0, 0, 0, *(eig_vals[1] * eig_vecs[:, 1]), color="b")
ax.quiver(0, 0, 0, *(eig_vals[2] * eig_vecs[:, 2]), color="g")
ax.set_xlim(-lims, lims)
ax.set_ylim(-lims, lims)
ax.set_zlim(-lims, lims)
plt.show()

# %% [markdown]
# ## References
